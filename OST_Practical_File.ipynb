# %% [markdown]
# <a href="https://colab.research.google.com/github/ShivangiiBisht/OST-Repo/blob/main/OST_Practical_File.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Conditional (if-else)
x = 10
if x > 5:
    print("x is greater than 5")
else:
    print("x is 5 or less")

# For loop
for i in range(5):
    print("Iteration:", i)

# While loop
count = 0
while count < 5:
    print("Count:", count)
    count += 1

# Function
def greet(name):
    return "Hello, " + name

print(greet("Student"))

# Combined example
def check_even(num):
    if num % 2 == 0:
        return "Even"
    else:
        return "Odd"

for i in range(1, 6):
    print(i, "is", check_even(i))
# Out:
# x is greater than 5
# Iteration: 0
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4
# Count: 0
# Count: 1
# Count: 2
# Count: 3
# Count: 4
# Hello, Student
# 1 is Odd
# 2 is Even
# 3 is Odd
# 4 is Even
# 5 is Odd

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset (upload file in Colab first)
df = pd.read_csv('boston_house_prices.csv', skiprows=1)

# View data
print(df.head())

# Basic analysis
print(df.describe())

# Plot (example: first two columns)
df.plot(x=df.columns[0], y=df.columns[1])

# Show graph
plt.show()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# ...
